# %%
import os
from typing import Literal
import zipfile

import dotenv
import instructor
import openai
from pydantic import BaseModel, Field

# %%
dotenv.load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Setting up for Extraction
#
# ### Properties to extract
#
# - What is the study design?
# - What hypotheses were being tested?
# - Methods for identifying follow up recommendations (including by a human and/or AI)
# - Methods for communicating follow up recommnendations
# - Methods for facillitating ordering / scheduling / completion of recommended follow up?
# - Methods for assessing if follow up recommendations are followed
# - Methods for assessing outcomes for patinets for whom follow up was recommended
# - Assessment of recommendation format on follow up being performed
#
# Exclusion criteria
# - Only a guidelines
# - Inumeration of follow up recommendation / incidental findings (incidence / prevalence)
# - Opinion only (editorial that does not describe a system)

# %%
class ArticleInfo(BaseModel):
    pmid: str = Field(description="PMID of the article")
    title: str = Field(description="Title of the article")
    about_imaging_followup_recommendations : bool | Literal['unknown'] = Field(description="Does the article discuss imaging follow-up recommendations? True or False; if you can't tell from the information, say 'unknown'")
    has_abstract: bool | Literal['unknown'] = Field(description="Does the article have an abstract? True or False; if you can't tell from the information, say 'unknown'")
    # study_design: str | Literal['unknown'] = Field(description="Study design of the article; if you can't tell from the information, say 'unknown'")
    # hypothesis: str  | Literal['unknown'] = Field(description="Hypothesis of the article; if you can't tell from the information, say 'unknown'")
    # identifying_recommendations_method: str | Literal['unknown'] = Field(description="How did the study identify recommendations; if you can't tell from the information, say 'unknown'")
    # communication_recommendations_method: str | Literal['unknown'] = Field(description="How did the program described communicate recommendations; if you can't tell from the information, say 'unknown'")
    # incidence_only: bool | Literal['unknown']= Field(description="Is the article only measuring the incidence of a particular recommendation? True or False; if you can't tell from the information, say 'unknown'")
    # guideline_only: bool | Literal['unknown'] = Field(description="Is the article only describing a guideline? True or False; if you can't tell from the information, say 'unknown'")
    # opinion_only: bool | Literal['unknown'] = Field(description="Is the article only an opinion piece or editorial? True or False; if you can't tell from the information, say 'unknown'")
    # review_only: bool | Literal['unknown'] = Field(description="Is the article only a review? True or False; if you can't tell from the information, say 'unknown'")

# %%
articles = {}

articles_zip = zipfile.ZipFile("data/entries_with_abstracts.zip", "r")
for filename in articles_zip.namelist():
    pmid = filename[0:-4]
    with articles_zip.open(filename) as f:
        articles[pmid] = f.read().decode("utf-8")

# %%
pmids = list(articles.keys())[:5]
print(pmids)
print(articles[pmids[0]])
# Out:
# ['100459', '10063862', '10071638', '10073588', '10077038']
# 456. Int J Oral Surg. 1978 Aug;7(4):400-4. doi: 10.1016/s0300-9785(78)80115-x.
#
# Follow-up investigation of reconstruction of the alveolar process in the
# atrophic mandible.
#
# Fazili M, von Overvest-Eerdmans GR, Vernooy AM, Visser WJ, von Waas MA.
#
# In this article the results are presented of the reconstruction of the alveolar
# process with iliac crest bone grafts in 14 patients. In all cases in a second
# operation a vestibuloplasty and a floor-of-mouth plasty was done. After an
# average follow-up period of 39 months, almost complete resorption of the bone
# grafts was observed. The clinical results varied. To obtain better results and
# avoid complications like pain at the donor and graft sites, mental nerve
# disturbances and other major problems associated with bone grafting, we prefer
# to perform the visor osteotomy in the future.
#
# DOI: 10.1016/s0300-9785(78)80115-x
# PMID: 100459 [Indexed for MEDLINE]

# %%
llm = instructor.from_openai(openai.OpenAI())

# %%
PROMPT = """You are a medical expert. You are given the title of a medical article about tracking follow-up recommendations in radiology.
Based on the title, you need to answer the following questions:
- Is the study about imaging follow-up recommendations? Note that this includes the idea of management of incidental findings 
  in radiology or other "clinically significant" findings/results in imaging exams.
- Does the article have an abstract? 
"""

"""
- What is the study design of the article? (e.g., cohort study, case-control study, randomized controlled trial, etc.)
- What is the hypothesis of the article?
- How did the study identify recommendations?
- How did the program described communicate recommendations?
- Is the article only measuring the incidence of a particular recommendation? True or False
- Is the article only describing a guideline? True or False
- Is the article only an opinion piece or editorial? True or False
- Is the article only a review? True or False
- Is the article only measuring the incidence of a particular recommendation? True or False
- Is the article only describing a guideline? True or False
"""

INSTRUCTIONS = """Answer the questions based ONLY on the given information. If you can't tell from the information, say 'unknown'."""

# %%
def generate_prompt(pmid: str) -> str:
    info = articles[pmid]
    return f"{PROMPT}\n\nArticle Information:\n\n{info}\n\n{INSTRUCTIONS}\n\nAnswer:"

# %%
pmids = list(articles.keys())[:100]
infos: list[ArticleInfo] = []
for pmid in pmids:
    response = llm.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": generate_prompt(pmid),
            }
        ],
        model="o4-mini",
        response_model=ArticleInfo,
    )

    print(response.model_dump_json(indent=2))
    infos.append(response)
# Out:
# {
#   "pmid": "100459",
#   "title": "Follow-up investigation of reconstruction of the alveolar process in the atrophic mandible.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10063862",
#   "title": "Methods of compliance with Mammography Quality Standards Act regulations for tracking positive mammograms: survey results",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "10071638",
#   "title": "[Rights and responsibilities of the radiologist in determining indications and applying radiologic procedures]",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10073588",
#   "title": "Primary hybrid total hip replacement, performed with insertion of the acetabular component without cement and a precoat femoral component with cement. An average ten-year follow-up study.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10077038",
#   "title": "Incidental detection of acute myocardial infarction during routine performance of three-dimensional dynamic MR angiographic study with dynamic injection of gadolinium",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10108145",
#   "title": "Tracking the elusive MRI referral pattern.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10116280",
#   "title": "An improved emergency department X-ray follow-up system",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10126027",
#   "title": "Consumer satisfaction and perceived quality of outpatient health services.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10130015",
#   "title": "Marketing strategies. Referring physicians. Part 3.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10130109",
#   "title": "Referring physician database: the cornerstone of a successful marketing program.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10132016",
#   "title": "Marketing strategies. Part 4: Payers.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10132454",
#   "title": "Problems with implementing guidelines: a randomised controlled trial of consensus management of dyspepsia.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10141110",
#   "title": "Understanding vertically integrated healthcare delivery systems.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10164377",
#   "title": "Specialist survival strategies",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10165112",
#   "title": "Info systems expand consulting role of radiologists.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10168904",
#   "title": "Software systems integration achieves cost-effective, clinically defensible, market-sensitive solutions.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10227361",
#   "title": "Guidance to users of Nycomed Amersham and North American Scientific, Inc., I-125 interstitial sources: dosimetry and calibration changes: recommendations of the American Association of Physicists in Medicine Radiation Therapy Committee Ad Hoc Subcommittee on Low-Energy Seed Dosimetry",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10244502",
#   "title": "Quality assurance programs for diagnostic radiology facilities: Food and Drug Administration. Final recommendation.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10271280",
#   "title": "Quality assurance in nuclear medicine facilities; availability of final recommendations--FDA. Notice.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": false
# }
# {
#   "pmid": "10285605",
#   "title": "Streamlining mobile mammography services. Concern over loss of quality.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10287341",
#   "title": "Strategic uses of teleradiology",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10337693",
#   "title": "Medical picture archiving and communication systems (PACS). Recommendations of the Committee of Computer Services of the German Research Society on compliance with recommendations of the university building code promotion law",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10342160",
#   "title": "Electronic imaging and clinical implementation: work group approach at Mayo Clinic, Rochester.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10342165",
#   "title": "Maintaining continuity of clinical operations while implementing large-scale filmless operations.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10342169",
#   "title": "Parlaying digital imaging and communications in medicine and open architecture to our advantage: the new Department of Defense picture archiving and communications system.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10349344",
#   "title": "Clinico-MRI study of hemispheric disorder in long-term follow-up cases of multiple system atrophy",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10361664",
#   "title": "Hardware failure in an unconstrained lumbar pedicle screw system. A 2-year follow-up study.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10386635",
#   "title": "American Brachytherapy Society (ABS) recommendations for transperineal permanent brachytherapy of prostate cancer",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10420909",
#   "title": "[MRI follow-up in multiple sclerosis. A guideline for quality assurance]",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "10436737",
#   "title": "An expert experiment--medico-legal expert testimony.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10470175",
#   "title": "Locoregional/systemic chemotherapy of locally advanced/metastasized pancreatic cancer with a combination of mitomycin-C and gemcitabine and simultaneous follow-up by imaging methods and tumor markers.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "10477029",
#   "title": "A method for implementing the American Association of Physicists in Medicine Task Group-43 dosimetry recommendations for 125I transperineal prostate seed implants on commercial treatment planning systems: regarding Luse et al. IJROBP 37:737-741; 1997.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10511663",
#   "title": "ASE/SCA guidelines for performing a comprehensive intraoperative multiplane transesophageal echocardiography examination: recommendations of the American Society of Echocardiography Council for Intraoperative Echocardiography and the Society of Cardiovascular Anesthesiologists Task Force for Certification in Perioperative Transesophageal Echocardiography.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10512257",
#   "title": "ASE/SCA guidelines for performing a comprehensive intraoperative multiplane transesophageal echocardiography examination: recommendations of the American Society of Echocardiography Council for Intraoperative Echocardiography and the Society of Cardiovascular Anesthesiologists Task Force for Certification in Perioperative Transesophageal Echocardiography.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10532051",
#   "title": "Consistency of care in surgery for scoliosis",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10541079",
#   "title": "PACS: new age radiology. Picture archiving and communication systems.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10541083",
#   "title": "PACS and radiology practice: enjoy the benefits but acknowledge the threats. Picture archiving and communications systems.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": false
# }
# {
#   "pmid": "10552159",
#   "title": "Evaluation of polyurethane stent implantation for the treatment of complete obstruction of the nasolacrimal system: 8-month follow-up and complications",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10575882",
#   "title": "Recommendations by the Swedish lung cancer group. Shorter waiting time is a quality requirement in the management of lung cancer",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10584778",
#   "title": "Malpractice issues in radiology. American College of Radiology Standard for Communication.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10586455",
#   "title": "Ten-year follow-up evaluation of a school screening program for scoliosis. Is the forward-bending test an accurate diagnostic criterion for the screening of scoliosis?",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10605325",
#   "title": "Are you well informed about roentgen referral and the medical product regulation?",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10609626",
#   "title": "Implanted functional electrical stimulation system for mobility in paraplegia: a follow-up case report.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10628599",
#   "title": "Long-term follow-up of survivors of acute lung injury: lack of effect of a ventilation strategy to prevent barotrauma",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10631652",
#   "title": "ISIS Survey: an international study on the diagnostic process and its implications in amyotrophic lateral sclerosis.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10671588",
#   "title": "Central nervous system sarcoidosis: follow-up at MR imaging during steroid therapy.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10688125",
#   "title": "National Electrical Manufacturers Association recommendations for implementing SPECT instrumentation quality control",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "10705003",
#   "title": "Quality of life in T1-3N0 prostate cancer patients treated with radiation therapy with minimum 10-year follow-up",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10752108",
#   "title": "Bridging the gap between science and practice in managing low back pain. A comprehensive spine care system in a health maintenance organization setting.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10802349",
#   "title": "American brachytherapy society recommendations for clinical implementation of NIST-1999 standards for (103)palladium brachytherapy",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10803052",
#   "title": "Radiotherapy of non-malignant diseases: principles and recommendations",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10823328",
#   "title": "Quantitative 201Tl SPET imaging in the follow-up of treatment for brain tumour: a sensitive tool for the early identification of response to chemotherapy?",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "10855048",
#   "title": "Neuromotor development and language processing in developmental dyspraxia: a follow-up case study.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10889401",
#   "title": "The exchange of radiotherapy data as part of an electronic patient-referral system.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10924378",
#   "title": "An audit of MRI for bone and soft-tissue tumours performed at referral centres.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "10924990",
#   "title": "The American Brachytherapy Society recommendations for high-dose-rate brachytherapy for carcinoma of the cervix.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11036339",
#   "title": "Risk of increased malignancy a reason for follow-up of low malignancy grade glioma. Early identification of high-risk patients is the key to good care",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "11038209",
#   "title": "Occult micro medullary thyroid carcinoma: therapeutic strategy and follow-up.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11051134",
#   "title": "Commission on Diagnostic Strategies: recommendations for functional neuroimaging of persons with epilepsy.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "11058646",
#   "title": "Tracking coronary calcification by using dual-section spiral CT: a 3-year follow-up",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11084152",
#   "title": "Management of simple thoracic injuries at a level I trauma centre: can primary health care system take over?",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11094525",
#   "title": "Pure titanium as bone substitute. Geometric and substance-specific aspects of computer-assisted fabrication and follow-up imaging",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "11128317",
#   "title": "Follow-up on \"Real-time B-mode ultrasound quality control test procedures\"",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "11129158",
#   "title": "Incidental findings of systemic thromboembolism in a case of tetralogy of Fallot by indium-111 oxine-labeled platelet scintigraphy.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "11181327",
#   "title": "Is it useful to perform a (67)gallium scintigraphy in the follow-up of patients with gastric lymphoma?",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "11186494",
#   "title": "How to develop and implement a successful marketing plan for radiology services.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "11200351",
#   "title": "The Legs for Life screening for peripheral vascular disease: compliance with physician recommendations in moderate- and high-risk assessed patients.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11216077",
#   "title": "[Need and quality assurance: can the introduction of the new generation mobile systems change the reference standards?]",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11237913",
#   "title": "Stereo nonmydriatic digital-video color retinal imaging compared with Early Treatment Diabetic Retinopathy Study seven standard field 35-mm stereo color photos for determining level of diabetic retinopathy.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11247488",
#   "title": "Origination of mediastinal hernia in late follow up period after performance of pulmonectomy",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11265654",
#   "title": "American Brachytherapy Society recommendations for clinical implementation of NIST-1999 standards for palladium-103 brachytherapy: in regard to Beyer et al. IJROBP 2000;47:273-275.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": false
# }
# {
#   "pmid": "11267826",
#   "title": "Follow-up of discrepancies in X-ray and electrocardiogram interpretations, and positive laboratory results.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11387963",
#   "title": "Clinical value of 99mTc-MIBI imaging, 131I whole body scan and HTG determination for the follow-up of patients with differentiated thyroid carcinoma after 131I therapy",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "11409552",
#   "title": "Autologous osteochondral transplantation using the diamond bone-cutting system (DBCS): 6-12 years' follow-up of 35 patients with osteochondral defects at the knee joint.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11429737",
#   "title": "Condylar process fractures in children: a follow-up study of fractures with total dislocation of the condyle from the glenoid fossa",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11464056",
#   "title": "Renal cell carcinoma: evaluation of the 1997 TNM system and recommendations for follow-up after surgery.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "11467919",
#   "title": "Explicit and incidental facial expression processing: an fMRI study.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11484975",
#   "title": "Analysis of a follow-up program for anal canal carcinoma.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "11491425",
#   "title": "Effect of femoral and tibial component position on patellar tracking following total knee arthroplasty: 10-year follow-up of Miller-Galante I knees.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11585880",
#   "title": "The Legs For Life Screening for Peripheral Vascular Disease: results of a prospective study designed to improve patient compliance with physician recommendations.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11587878",
#   "title": "The spectrum of neurologic disease in children with systemic cancer.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11606872",
#   "title": "Shared patient analysis: a method to assess the clinical benefits of patient referrals.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11700446",
#   "title": "Determination of the \"incidental\" Lund score for the staging of chronic rhinosinusitis.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11724050",
#   "title": "Congressional update: Report from the biomedical imaging program of the National Cancer Institute. Research recommendations from a lung cancer screening workshop.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "11727095",
#   "title": "Clinical efficacy of the Toupet technique performed by laparoscopic surgery. Medium-term follow-up in 122 cases.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11731862",
#   "title": "Determining optimal MRI follow-up after transsphenoidal surgery for pituitary adenoma: scan at 24 hours postsurgery provides reliable information.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "11764394",
#   "title": "Recommendations for a mammography quality assurance program.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11788690",
#   "title": "Evaluation of Legs For Life National Screening and Awareness Program for Peripheral Vascular Disease: results of a follow-up survey of screening participants",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11792407",
#   "title": "The neural correlates of intentional and incidental self processing.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11794915",
#   "title": "Family physicians' initiative to increase compliance with screening mammography--an innovative community project.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11795925",
#   "title": "An audit of hip radiographs performed for general practitioners.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11847619",
#   "title": "Minimum 5-year follow-up and radiologic analysis of the all-polyethylene tibial component of the Kinemax Plus system.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11869629",
#   "title": "Follow-up strategies for patients treated for non-metastatic colorectal cancer",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "11870486",
#   "title": "Guidelines and algorithms: strategies for standardization of referral criteria in diagnostic radiology.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "11922709",
#   "title": "Identification of treated target points for parkinsonism on gamma knife follow-up MR images",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "12058127",
#   "title": "Role of perioperative biological tests during the performance and follow-up of corticotroph adenoma exeresis",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "12079905",
#   "title": "Laboratory and imaging studies used by French rheumatologists to determine the cause of recent onset polyarthritis without extra-articular manifestations.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "12107948",
#   "title": "Endoscopic ultrasound-guided biopsy of suspected malignancy in the mediastinum has a major impact on the clinical decision process",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "12146993",
#   "title": "Systematic postoperative radiologic follow-up in patients with non-small cell lung cancer for detecting second primary lung cancer in stage IA",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "12187021",
#   "title": "Follow-up examinations by transcranial Doppler ultrasound in primary angiitis of the central nervous system.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }

# %%
with open("data/entries_with_abstracts_0_100.jsonl", "w") as f:
    for info in infos:
        f.write(info.model_dump_json() + "\n")

# %%
import csv

with open("data/entries_with_abstracts_0_100.csv", "w", newline='', encoding="utf-8") as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=infos[0].model_dump().keys())
    writer.writeheader()
    for info in infos:
        writer.writerow(info.model_dump())

# %%
s="""38147905
36922265
36650302
35752517
33607066
29728325
24294680
37879972
37302681
29305076
28434846
36063362
30779667
36564264
36922106
23548405
32220539
30860895
22195225
31452006
37073901
27832518
18647895
19703870
20884911
29179912
34076452
36287625
37236842
31206047
28742377
36759382
37820835
36521629
36411090
36922107
36792996
37000450
35867062
35773813
35788428
35186516
32827469
34374592
32857982
33478839
33278340
33984286
32294771
20308458"""
good_pmids = s.splitlines()

# %%
good_infos: list[ArticleInfo] = []
for pmid in good_pmids:
    if pmid not in articles:
        print(f"PMID {pmid} not found in articles.")
        continue
    response = llm.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": generate_prompt(pmid),
            }
        ],
        model="o4-mini",
        response_model=ArticleInfo,
    )

    print(response.model_dump_json(indent=2))
    good_infos.append(response)
# Out:
# {
#   "pmid": "38147905",
#   "title": "Financial Impact of a Radiology Safety Net Program for Resolution of Clinically Necessary Follow-up Imaging Recommendations",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "36922265",
#   "title": "White Paper: Best Practices in the Communication and Management of Actionable Incidental Findings in Emergency Department Imaging.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "36650302",
#   "title": "Implementing a Streamlined Radiology Workflow to Close the Loop on Incidental Imaging Findings in the Emergency Department",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "35752517",
#   "title": "Catching Those Who Fall Through the Cracks: Integrating a Follow-Up Process for Emergency Department Patients with Incidental Radiologic Findings",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "33607066",
#   "title": "Improvement in Follow-up Imaging With a Patient Tracking System and Computerized Registry for Lung Nodule Management.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "29728325",
#   "title": "Science to Practice: IT Solutions to Drive Standardized Report Recommendations for Abdominal Aortic Aneurysm Surveillance",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "24294680",
#   "title": "An initiative to improve the management of clinically significant test results in a large health care network.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "37879972",
#   "title": "The Value of Using a Quality Assurance Follow-Up Team to Address Incidental Findings After Emergency Department or Urgent Care Discharge: A Cost Analysis.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "37302681",
#   "title": "The Effect of Using Artificial Intelligence to Improve Compliance Rates for Imaging Follow-Up Recommendations.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": "unknown"
# }
# {
#   "pmid": "29305076",
#   "title": "System-Level Process Change Improves Communication and Follow-Up for Emergency Department Patients With Incidental Radiology Findings",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "28434846",
#   "title": "Effect of an Automated Tracking Registry on the Rate of Tracking Failure in Incidental Pulmonary Nodules",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "36063362",
#   "title": "System-driven longitudinal follow-up of incidental imaging findings",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "30779667",
#   "title": "Adoption of a Closed-Loop Communication Tool to Establish and Execute a Collaborative Follow-Up Plan for Incidental Pulmonary Nodules.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "36564264",
#   "title": "Alerts and notification of imaging reports recommendations.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": "unknown"
# }
# PMID 36922106 not found in articles.
# {
#   "pmid": "23548405",
#   "title": "Automated detection using natural language processing of radiologists recommendations for additional imaging of incidental findings",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "32220539",
#   "title": "Closing the Loop-A Pilot in Health System Improvement.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "30860895",
#   "title": "Automated Tracking of Follow-Up Imaging Recommendations",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "22195225",
#   "title": "Automatic identification of critical follow-up recommendation sentences in radiology reports.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "31452006",
#   "title": "Determining Follow-Up Imaging Study Using Radiology Reports",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "37073901",
#   "title": "Development and External Validation of an Artificial Intelligence Model for Identifying Radiology Reports Containing Recommendations for Additional Imaging",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "27832518",
#   "title": "Expanding the Scope of an Automated Radiology Recommendation-Tracking Engine: Initial Experiences and Lessons Learned",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "18647895",
#   "title": "Extraction of recommendation features in radiology with natural language processing: exploratory study",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "19703870",
#   "title": "Important imaging finding e-mail alert system: experience after 3 years of implementation",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "20884911",
#   "title": "Electronic messaging system for communicating important, but nonemergent, abnormal imaging results.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "29179912",
#   "title": "Filling the void: a low-cost, high-yield approach to addressing incidental findings in trauma patients.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "34076452",
#   "title": "Notification System for Overdue Radiology Recommendations Improves Rates of Follow-Up and Diagnosis",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "36287625",
#   "title": "Predictors of Completion of Clinically Necessary Radiologist-Recommended Follow-Up Imaging: Assessment Using an Automated Closed-Loop Communication and Tracking Tool",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "37236842",
#   "title": "Revenue and Cost Analysis of a System Utilizing Natural Language Processing and a Nurse Coordinator for Radiology Follow-up Recommendations",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "31206047",
#   "title": "Process improvement for follow-up radiology report recommendations of lung nodules.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "28742377",
#   "title": "Reducing Delay in Diagnosis: Multistage Recommendation Tracking.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "36759382",
#   "title": "The FIND Program: Improving Follow-up of Incidental Imaging Findings",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "37820835",
#   "title": "Impact of Early Direct Patient Notification on Follow-Up Completion for Nonurgent Actionable Incidental Radiologic Findings",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "36521629",
#   "title": "A Standardized Radiology Template Improves Incidental Adrenal Mass Follow-Up: A Prospective Effectiveness and Implementation Study.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# PMID 36411090 not found in articles.
# {
#   "pmid": "36922107",
#   "title": "Implementation of Incidental Liver Lesion Clinically Integrated Workflow Increases Compliance With ACR Follow-Up Guidelines, Closing Care Gaps.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "36792996",
#   "title": "Incidental Findings Protocol Implementation at a Level-I Trauma Center: A Review of Patient Follow-Up",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# PMID 37000450 not found in articles.
# {
#   "pmid": "35867062",
#   "title": "Analysis of Radiology Report Recommendation Characteristics and Rate of Recommended Action Performance.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "35773813",
#   "title": "Impact of Follow-Up Imaging Recommendation Specificity on Adherence",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "35788428",
#   "title": "Automated Notification of Relevant Expected or Incidental Findings in Imaging Exams in a Verticalized Healthcare System.",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# PMID 35186516 not found in articles.
# {
#   "pmid": "32827469",
#   "title": "Implementation and Impact of a Comprehensive Radiology Report Categorization System on Communication of Important Results",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "34374592",
#   "title": "Electronic Health Record Closed-Loop Communication Program for Unexpected Nonemergent Findings",
#   "about_imaging_followup_recommendations": false,
#   "has_abstract": true
# }
# {
#   "pmid": "32857982",
#   "title": "Factors Affecting Adherence to Recommendations for Additional Imaging of Incidental Findings in Radiology Reports",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "33478839",
#   "title": "RADAR: A Closed-Loop Quality Improvement Initiative Leveraging A Safety Net Model for Incidental Pulmonary Nodule Management.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "33278340",
#   "title": "Management Strategies to Promote Follow-Up Care for Incidental Findings: A Scoping Review",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# PMID 33984286 not found in articles.
# PMID 32294771 not found in articles.
# {
#   "pmid": "20308458",
#   "title": "Compliance with Fleischner Society guidelines for management of small lung nodules: a survey of 834 radiologists.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }

# %%
with open("data/likely_entries.csv", "w", newline='', encoding="utf-8") as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=good_infos[0].model_dump().keys())
    writer.writeheader()
    for info in good_infos:
        writer.writerow(info.model_dump())

# %%
recheck_pmids = ["24294680", "19703870", "35788428", "34374592"]
for pmid in recheck_pmids:
    response = llm.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": generate_prompt(pmid),
            }
        ],
        model="o4-mini",
        response_model=ArticleInfo,
    )

    print(response.model_dump_json(indent=2))
# Out:
# {
#   "pmid": "24294680",
#   "title": "An initiative to improve the management of clinically significant test results in a large health care network",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "19703870",
#   "title": "Important imaging finding e-mail alert system: experience after 3 years of implementation.",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "35788428",
#   "title": "Automated Notification of Relevant Expected or Incidental Findings in Imaging Exams in a Verticalized Healthcare System",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
# {
#   "pmid": "34374592",
#   "title": "Electronic Health Record Closed-Loop Communication Program for Unexpected Nonemergent Findings",
#   "about_imaging_followup_recommendations": true,
#   "has_abstract": true
# }
